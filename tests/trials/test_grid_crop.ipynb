# %%
import sys
sys.path.insert(0, '..') # krystal package is 1 level down

# %%
from krystal import image as kim
from krystal import imagetrans as it

# %%
from pathlib import Path
bpath  = Path("../data") ; bpath
# Out:
# PosixPath('../data')

# %%
im = kim.imread(bpath / "images1" / "mushrooms.jpg")
type(im), im.shape
# Out:
# (numpy.ndarray, (433, 650, 3))

# %%
kim.imshow(im)

# %%
crg1,__ = it.gridcrop(im, 128) ; crg1
# Out:
# [[0, 0],
#  [0, 130],
#  [0, 261],
#  [0, 391],
#  [0, 522],
#  [0, 522],
#  [152, 0],
#  [152, 130],
#  [152, 261],
#  [152, 391],
#  [152, 522],
#  [152, 522],
#  [304, 0],
#  [304, 130],
#  [304, 261],
#  [304, 391],
#  [304, 522],
#  [304, 522]]

# %%
imlist = it.imgcut(im, 256, crg1) ; len(imlist)
# Out:
# 18

# %%
kim.imgrid(imlist, 5, 10, 20)
