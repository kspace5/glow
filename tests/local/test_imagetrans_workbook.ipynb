# %%
from pathlib import Path
#from enum import Enum

# %%
import sys
sys.path.insert(0, '..') # krystal package is 2 levels down

# %%
#sys.path

# %%
from krystal import imagetrans as ki

# %%
bpath  = Path("../data") ; bpath
# Out:
# PosixPath('../data')

# %%
from krystal import image as kim

# %%
im = kim.imread(bpath / "images1" / "mushrooms.jpg")

# %%
type(im)
# Out:
# numpy.ndarray

# %%
kim.imshow(im)

# %%
#kim.vidshow(bpath / "vids" / "file_example_MP4_640_3MG.mp4")

# %%
im.size
# Out:
# 844350

# %%
im.shape[0]
# Out:
# 433

# %%
 h, w = im.shape[0], im.shape[1]

# %%
w, h
# Out:
# (650, 433)

# %%
t = 256

# %%
import math as M

# %%
lp = (w - t)

# %%
lp
# Out:
# 394

# %%
import numpy as np

# %%
ts = np.linspace(0, lp, 5).astype(int) ; ts
# Out:
# array([  0,  98, 197, 295, 394])

# %%
88 + 256/2, 433 / 2 # Proof that using an odd number of splits get the ccenter crop
# Out:
# (216.0, 216.5)

# %%
177 + 256
# Out:
# 433

# %%
ts
# Out:
# array([  0,  98, 197, 295, 394])

# %%
ts  = ts[..., np.newaxis] ; ts
# Out:
# array([[  0],
#        [ 98],
#        [197],
#        [295],
#        [394]])

# %%
tl = np.full(ts.shape[0], 125) ;

# %%
tl = tl[..., np.newaxis]; tl
# Out:
# array([[125],
#        [125],
#        [125],
#        [125],
#        [125]])

# %%
res = np.append(ts, tl,axis=1);  res
# Out:
# array([[  0, 125],
#        [ 98, 125],
#        [197, 125],
#        [295, 125],
#        [394, 125]])

# %%
t2 = np.array([[0, 255]]) ; t2
# Out:
# array([[  0, 255]])

# %%
np.repeat(t2, 5, axis=0)
# Out:
# array([[  0, 255],
#        [  0, 255],
#        [  0, 255],
#        [  0, 255],
#        [  0, 255]])
