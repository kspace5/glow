# %%
import sys
sys.path.insert(0, '..') # krystal package is 1 level down

# %%
from krystal import imagetrans as it

# %%
from pathlib import Path

# %%
from krystal import imagetrans as kt

# %%
import numpy as np

# %%
bpath  = Path("../data") ; bpath
# Out:
# PosixPath('../data')

# %%
from krystal import image as kim

# %%
im = kim.imread(bpath / "images1" / "mushrooms.jpg")

# %%
type(im), im.shape
# Out:
# (numpy.ndarray, (433, 650, 3))

# %%
kim.imshow(im)

# %% [markdown]
# Find the optimized value of trim_tolerance below

# %%
t  = 256
trim_tolerance = 0.6
crg1,__ = kt.gridcrop(im, t, trim_tolerance) ; crg1
# Out:
# [[0, 0], [0, 393], [177, 0], [177, 393]]

# %%
kt.find_optimalcropcount(im, t), im.shape
# Out:
# ((2, 1, True, True), (433, 650, 3))

# %%
imlist = kt.imgcut(im, t, crg1) ; len(imlist) ; crg1
# Out:
# [[0, 0], [0, 393], [177, 0], [177, 393]]

# %%
w = 433
(w % t) / t
# Out:
# 0.69140625

# %%
kim.imgrid(imlist, 5, 10, 20)
