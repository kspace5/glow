# %%
import krystal.utils as ku
from pathlib import Path
import sys

# %% [markdown]
# ## filePathList and fileNameList

# %%
ku.is_notebook()
# Out:
# True

# %%
# ku.fileNameList?

# %%
try:
    ku.filePathList(Path("../temp/frames2"))
except Exception as e:
    print("Unexpected error:", str(e))
except:
    print("Unexpected error:", sys.exc_info()[0])
# Out:
# Path does not exist
# Unexpected error: Path does not exist

# %%
ku.fileNameList(Path("../temp/frames"), "img??.png")
# Out:
# ['img10.png',
#  'img20.png',
#  'img25.png',
#  'img30.png',
#  'img35.png',
#  'img40.png',
#  'img45.png',
#  'img50.png',
#  'img55.png',
#  'img60.png',
#  'img65.png',
#  'img70.png',
#  'img75.png',
#  'img80.png',
#  'img85.png',
#  'img90.png',
#  'img95.png',
#  'img15.png']

# %%
ku.fileNameList(Path("../temp/frames"), "img*.*")
# Out:
# ['img0.png',
#  'img10.png',
#  'img100.png',
#  'img1000.png',
#  'img1005.png',
#  'img1010.png',
#  'img1015.png',
#  'img1020.png',
#  'img1025.png',
#  'img1030.png',
#  'img1035.png',
#  'img1040.png',
#  'img1045.png',
#  'img105.png',
#  'img1050.png',
#  'img1055.png',
#  'img1060.png',
#  'img1065.png',
#  'img1070.png',
#  'img185.png',
#  'img190.png',
#  'img195.png',
#  'img20.png',
#  'img200.png',
#  'img205.png',
#  'img210.png',
#  'img215.png',
#  'img220.png',
#  'img225.png',
#  'img230.png',
#  'img235.png',
#  'img240.png',
#  'img245.png',
#  'img25.png',
#  'img250.png',
#  'img255.png',
#  'img260.png',
#  'img265.png',
#  'img275.png',
#  'img280.png',
#  'img285.png',
#  'img290.png',
#  'img295.png',
#  'img30.png',
#  'img300.png',
#  'img305.png',
#  'img310.png',
#  'img315.png',
#  'img320.png',
#  'img325.png',
#  'img330.png',
#  'img335.png',
#  'img340.png',
#  'img345.png',
#  'img35.png',
#  'img350.png',
#  'img355.png',
#  'img365.png',
# ...
